# %% [markdown]
# # 02 获取并检查行情
#
# 免费接口没有稳定性保证。真实下载必须显式开启；空响应、字段变化和网络失败会抛出错误。

# %%
from datetime import date
from investkb.data.providers import AKShareProvider
from investkb.validation.market import validate_bars

RUN_NETWORK = False
if RUN_NETWORK:
    bars = AKShareProvider().daily_bars('CN', '600000', date(2024, 1, 1), date(2024, 3, 31), 'qfq')
    print(bars.tail())
    print(validate_bars(bars))

# %% [markdown]
# 在研究前记录市场、代码、复权方式、来源、抓取时间和数据截止日。下载成功不等于数据正确。
